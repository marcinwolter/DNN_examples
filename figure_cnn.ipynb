# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/DNN_examples/blob/master/figure_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple convnet on the generated set of figures (circle, triangle, square)
'''
from __future__ import print_function


# !pip install keras_sequential_ascii

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Reshape
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation
from keras import backend as K
from keras_sequential_ascii import sequential_model_to_ascii_printout
from keras.utils import plot_model
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.constraints import maxnorm
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras import metrics

from PIL import Image, ImageDraw

import time
import math
# Out:
# Collecting keras_sequential_ascii
#   Downloading https://files.pythonhosted.org/packages/2d/a4/806e3ed5d7ac7463e2fae77e09ccccc88c78266b248fb637e4efa4f65ec0/keras_sequential_ascii-0.1.1.tar.gz
# Requirement already satisfied: keras in /usr/local/lib/python2.7/dist-packages (from keras_sequential_ascii) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.16.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.2.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.12.0)
# Building wheels for collected packages: keras-sequential-ascii
#   Building wheel for keras-sequential-ascii (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/f5/8d/81/912666dff82a923ce423a7e797cd75f54271c7031512cdb282
# Successfully built keras-sequential-ascii
# Installing collected packages: keras-sequential-ascii
# Successfully installed keras-sequential-ascii-0.1.1
# Using TensorFlow backend.

# %%
batch_size = 128
num_classes = 3
epochs = 256 #12

np.random.seed(2348)

batch_size_gen = 60000
batch_size_val = 10000

# input image dimensions
img_rows, img_cols = 32, 32
img_shape = (img_rows, img_cols)


#probability of noise and the efficiency<1
prob_noise = 0.50

# %%
def gen_noise(batch_size_gen=batch_size_gen, img_shape=img_shape, prob_noise=prob_noise):

        batch_events = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        for n in range(batch_size_gen):

            for i in range(img_shape[0]):
               for j in range(img_shape[1]):
                 if np.random.random()<prob_noise:
                     batch_events[n,0,i,j]=1


        yield batch_events

# %%
### generate geometrical figures

def generate_circle(r, x0, y0, img_shape):
    """
    Generate a single circle.
    Parameters:
        r: radius
        x0,y0: position of the circle center
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.ellipse((x0-r, y0-r, x0+r, y0+r), outline ='white')
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
def generate_square(d, x0, y0, angle, img_shape):
    """
    Generate a square.
    Parameters:
        d: size
        x0,y0: position of the square center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.rectangle((x0-d/2, y0-d/2, x0+d/2, y0+d/2), outline ='white')
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
def generate_triangle(d, x0, y0, angle, img_shape):
    """
    Generate a square.
    Parameters:
        d: size 
        x0,y0: position of the square center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    dd = d/math.sqrt(3)
    draw.polygon(((x0-d/2, y0-dd/2), (x0+d/2, y0-dd/2), (x0,y0+dd)), outline ='white')
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
# generate a random number
def rand_interval(a = 0., b = 1.):
   rnd = a + (b-a)*np.random.random()
   return rnd

# %%
# Generator for random figures
# Each image contains exactly one object (circle, triangle, square)
def gen_n_figures(batch_size_gen=batch_size_gen, img_shape=img_shape):

        batch_events  = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        batch_targets =-np.ones((batch_size_gen, 1, 1 ))

        for n in range(batch_size_gen):
            
            k = np.random.randint(0,3)
            
            r = rand_interval(img_cols*0.15, img_cols*0.5)
            d = rand_interval(img_cols*0.15, img_cols*0.7) 
            l = rand_interval(img_cols*0.15, img_cols*0.7)
            x0 = rand_interval(0.33*img_cols, 0.66*img_cols)       
            y0 = rand_interval(0.33*img_rows, 0.66*img_rows)     
            alpha = 360.*np.random.random()  

            if k == 0:
               batch_events[n,0] = generate_circle(r, x0, y0, img_shape)
            elif k == 1:
               batch_events[n,0] = generate_square(d, x0, y0, alpha, img_shape)
            elif k == 2:
               batch_events[n,0] = generate_triangle(l, x0, y0, alpha, img_shape)
            else:
               print("Wrong figure id!!!")
            batch_targets[n,0] = k
            


        yield batch_events, batch_targets

# %%
#generate training and validation dataset
xx_train, yy_train = gen_n_figures(batch_size_gen, img_shape).next()
xx_test, yy_test   = gen_n_figures(batch_size_val, img_shape).next()
xx_val, yy_val     = gen_n_figures(batch_size_val, img_shape).next()


# add noise
xx_train = xx_train + gen_noise(batch_size_gen, img_shape).next()
xx_test  = xx_test  + gen_noise(batch_size_val, img_shape).next()
xx_val   = xx_val  + gen_noise(batch_size_val, img_shape).next()

#and clip to get maximum 1
xx_train = np.clip(xx_train, 0, 1)
xx_test  = np.clip(xx_test, 0, 1)
xx_val   = np.clip(xx_val, 0, 1)

# %%
#plot 100 figures (random offset)
class_names = ['circle','square','triangle']


def plot_images(plot_size=6):
  offset = max(0, min(batch_size_gen-plot_size*plot_size, np.random.randint(0,batch_size_gen/2)))
  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for n in range(min(plot_size*plot_size,len(xx_train))):
    ax = plt.subplot(plot_size, plot_size, n+1)
    ax.imshow(xx_train[n+offset,0])
    ax.set_title(class_names[int(yy_train[n+offset,0])])
    ax.axis('off')

  plt.show()
  #plt.savefig('event.png')
  #plt.clf()
  
plot_images(6)
plot_images(6)
plot_images(6)
plot_images(2)
plot_images(2)
plot_images(2)
plot_images(2)

# %%
# Convert and pre-processing

yy_train = np_utils.to_categorical(yy_train, num_classes)
yy_test = np_utils.to_categorical(yy_test, num_classes)
yy_val = np_utils.to_categorical(yy_val, num_classes)

print("yy_train ",yy_train.shape)
# Out:
# yy_train  (60000, 1, 3)

# %%
# Define Model

def base_model():

    model = Sequential()
    input_shape=(1,img_rows,img_cols)

    model.add(Reshape((img_rows,img_cols,1),input_shape=input_shape))


    model.add(Conv2D(img_rows, (3, 3), padding='same', activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(img_rows,(3,3),padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dropout(rate = 0.2))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))


    model.add(Dense(num_classes, activation='softmax'))

    model.add(Reshape((1,num_classes),input_shape=(num_classes,)))

#    sgd = SGD(lr = 0.1, decay=1e-6, nesterov=True)
    sgd = SGD(lr = 0.01, decay=1e-6, nesterov=True)

# Train model

    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=[metrics.categorical_accuracy])   # 'accuracy'
    return model

# %%
# Vizualizing model structure
# Model summary (ascii)
cnn_n = base_model()
cnn_n.summary()

# Model printout (ascii)
sequential_model_to_ascii_printout(cnn_n)

# Plotting model in graphical mode
plot_model(cnn_n)   ###, to_file='model.png')  ###, show_shapes=True
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0716 13:43:48.049382 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0716 13:43:48.097810 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0716 13:43:48.118546 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0716 13:43:48.154441 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0716 13:43:48.168620 140367082821504 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0716 13:43:48.205185 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0716 13:43:48.426856 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0716 13:43:48.439177 140367082821504 deprecation_wrapper.py:119] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1, 3)              0
# =================================================================
# Total params: 3,437,283
# Trainable params: 3,437,283
# Non-trainable params: 0
# _________________________________________________________________
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####      1   32   32
#              Reshape     |   -------------------         0     0.0%
#                        #####     32   32    1
#               Conv2D    \|/  -------------------       320     0.0%
#                 relu   #####     32   32   32
#              Dropout    | || -------------------         0     0.0%
#                        #####     32   32   32
#               Conv2D    \|/  -------------------      9248     0.0%
#                 relu   #####     32   32   32
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####     16   16   32
#               Conv2D    \|/  -------------------     18496     0.0%
#                 relu   #####     16   16   64
#              Dropout    | || -------------------         0     0.0%
#                        #####     16   16   64
#               Conv2D    \|/  -------------------     36928     1.0%
#                 relu   #####     16   16   64
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      8    8   64
#               Conv2D    \|/  -------------------     73856     2.0%
#                 relu   #####      8    8  128
#              Dropout    | || -------------------         0     0.0%
#                        #####      8    8  128
#               Conv2D    \|/  -------------------    147584     4.0%
#                 relu   #####      8    8  128
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      4    4  128
#              Flatten   ||||| -------------------         0     0.0%
#                        #####        2048
#              Dropout    | || -------------------         0     0.0%
#                        #####        2048
#                Dense   XXXXX -------------------   2098176    61.0%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------   1049600    30.0%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------      3075     0.0%
#              softmax   #####           3
#              Reshape     |   -------------------         0     0.0%
#                        #####      1    3

# %%
# patient early stopping
es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=10)
mc = ModelCheckpoint('best_model.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)
# fit model
cnn = cnn_n.fit(xx_train, yy_train, batch_size=batch_size, epochs=epochs, validation_data=(xx_test,yy_test),shuffle=True, callbacks=[es, mc])
# load the saved model
saved_model = load_model('best_model.h5')
# Out:
# W1120 22:10:44.687134 140531695249280 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1120 22:10:44.977423 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1120 22:10:45.053776 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W1120 22:10:45.166410 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1120 22:10:45.175190 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1120 22:10:45.176491 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W1120 22:10:45.291904 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1120 22:10:45.293910 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# W1120 22:10:45.396132 140531695249280 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 60000/60000 [==============================] - 22s 370us/step - loss: 1.0992 - categorical_accuracy: 0.3340 - val_loss: 1.0984 - val_categorical_accuracy: 0.3374
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.33740, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 1.0985 - categorical_accuracy: 0.3427 - val_loss: 1.0981 - val_categorical_accuracy: 0.3346
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.33740
# Epoch 3/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.0980 - categorical_accuracy: 0.3456 - val_loss: 1.0976 - val_categorical_accuracy: 0.3369
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.33740
# Epoch 4/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 1.0970 - categorical_accuracy: 0.3620 - val_loss: 1.0964 - val_categorical_accuracy: 0.3346
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.33740
# Epoch 5/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 1.0941 - categorical_accuracy: 0.3786 - val_loss: 1.0920 - val_categorical_accuracy: 0.3373
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.33740
# Epoch 6/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 1.0770 - categorical_accuracy: 0.4190 - val_loss: 1.0486 - val_categorical_accuracy: 0.4832
#
# Epoch 00006: val_categorical_accuracy improved from 0.33740 to 0.48320, saving model to best_model.h5
# Epoch 7/256
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.9979 - categorical_accuracy: 0.4841 - val_loss: 0.9475 - val_categorical_accuracy: 0.5249
#
# Epoch 00007: val_categorical_accuracy improved from 0.48320 to 0.52490, saving model to best_model.h5
# Epoch 8/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.9568 - categorical_accuracy: 0.5152 - val_loss: 0.9605 - val_categorical_accuracy: 0.5269
#
# Epoch 00008: val_categorical_accuracy improved from 0.52490 to 0.52690, saving model to best_model.h5
# Epoch 9/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.9425 - categorical_accuracy: 0.5221 - val_loss: 0.9382 - val_categorical_accuracy: 0.5395
#
# Epoch 00009: val_categorical_accuracy improved from 0.52690 to 0.53950, saving model to best_model.h5
# Epoch 10/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.9236 - categorical_accuracy: 0.5342 - val_loss: 0.8883 - val_categorical_accuracy: 0.5582
#
# Epoch 00010: val_categorical_accuracy improved from 0.53950 to 0.55820, saving model to best_model.h5
# Epoch 11/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.9076 - categorical_accuracy: 0.5422 - val_loss: 0.8952 - val_categorical_accuracy: 0.5601
#
# Epoch 00011: val_categorical_accuracy improved from 0.55820 to 0.56010, saving model to best_model.h5
# Epoch 12/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.8894 - categorical_accuracy: 0.5548 - val_loss: 0.8458 - val_categorical_accuracy: 0.5818
#
# Epoch 00012: val_categorical_accuracy improved from 0.56010 to 0.58180, saving model to best_model.h5
# Epoch 13/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.8689 - categorical_accuracy: 0.5656 - val_loss: 0.8916 - val_categorical_accuracy: 0.5555
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.58180
# Epoch 14/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.8431 - categorical_accuracy: 0.5854 - val_loss: 0.8053 - val_categorical_accuracy: 0.6156
#
# Epoch 00014: val_categorical_accuracy improved from 0.58180 to 0.61560, saving model to best_model.h5
# Epoch 15/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.8148 - categorical_accuracy: 0.6018 - val_loss: 0.7539 - val_categorical_accuracy: 0.6400
#
# Epoch 00015: val_categorical_accuracy improved from 0.61560 to 0.64000, saving model to best_model.h5
# Epoch 16/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.7834 - categorical_accuracy: 0.6197 - val_loss: 0.7208 - val_categorical_accuracy: 0.6591
#
# Epoch 00016: val_categorical_accuracy improved from 0.64000 to 0.65910, saving model to best_model.h5
# Epoch 17/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.7518 - categorical_accuracy: 0.6412 - val_loss: 0.6846 - val_categorical_accuracy: 0.6803
#
# Epoch 00017: val_categorical_accuracy improved from 0.65910 to 0.68030, saving model to best_model.h5
# Epoch 18/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.7235 - categorical_accuracy: 0.6545 - val_loss: 0.6526 - val_categorical_accuracy: 0.6953
#
# Epoch 00018: val_categorical_accuracy improved from 0.68030 to 0.69530, saving model to best_model.h5
# Epoch 19/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.6945 - categorical_accuracy: 0.6718 - val_loss: 0.6253 - val_categorical_accuracy: 0.7053
#
# Epoch 00019: val_categorical_accuracy improved from 0.69530 to 0.70530, saving model to best_model.h5
# Epoch 20/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.6670 - categorical_accuracy: 0.6876 - val_loss: 0.6032 - val_categorical_accuracy: 0.7159
#
# Epoch 00020: val_categorical_accuracy improved from 0.70530 to 0.71590, saving model to best_model.h5
# Epoch 21/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.6403 - categorical_accuracy: 0.7020 - val_loss: 0.5787 - val_categorical_accuracy: 0.7342
#
# Epoch 00021: val_categorical_accuracy improved from 0.71590 to 0.73420, saving model to best_model.h5
# Epoch 22/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.6168 - categorical_accuracy: 0.7136 - val_loss: 0.6224 - val_categorical_accuracy: 0.7074
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.73420
# Epoch 23/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.5962 - categorical_accuracy: 0.7225 - val_loss: 0.5335 - val_categorical_accuracy: 0.7558
#
# Epoch 00023: val_categorical_accuracy improved from 0.73420 to 0.75580, saving model to best_model.h5
# Epoch 24/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.5737 - categorical_accuracy: 0.7361 - val_loss: 0.5091 - val_categorical_accuracy: 0.7684
#
# Epoch 00024: val_categorical_accuracy improved from 0.75580 to 0.76840, saving model to best_model.h5
# Epoch 25/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.5494 - categorical_accuracy: 0.7467 - val_loss: 0.4902 - val_categorical_accuracy: 0.7792
#
# Epoch 00025: val_categorical_accuracy improved from 0.76840 to 0.77920, saving model to best_model.h5
# Epoch 26/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.5281 - categorical_accuracy: 0.7602 - val_loss: 0.4862 - val_categorical_accuracy: 0.7750
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.77920
# Epoch 27/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.5085 - categorical_accuracy: 0.7691 - val_loss: 0.4540 - val_categorical_accuracy: 0.7970
#
# Epoch 00027: val_categorical_accuracy improved from 0.77920 to 0.79700, saving model to best_model.h5
# Epoch 28/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.4936 - categorical_accuracy: 0.7773 - val_loss: 0.4446 - val_categorical_accuracy: 0.8000
#
# Epoch 00028: val_categorical_accuracy improved from 0.79700 to 0.80000, saving model to best_model.h5
# Epoch 29/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4767 - categorical_accuracy: 0.7855 - val_loss: 0.4313 - val_categorical_accuracy: 0.8092
#
# Epoch 00029: val_categorical_accuracy improved from 0.80000 to 0.80920, saving model to best_model.h5
# Epoch 30/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.4602 - categorical_accuracy: 0.7933 - val_loss: 0.4257 - val_categorical_accuracy: 0.8119
#
# Epoch 00030: val_categorical_accuracy improved from 0.80920 to 0.81190, saving model to best_model.h5
# Epoch 31/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4468 - categorical_accuracy: 0.8008 - val_loss: 0.4000 - val_categorical_accuracy: 0.8222
#
# Epoch 00031: val_categorical_accuracy improved from 0.81190 to 0.82220, saving model to best_model.h5
# Epoch 32/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4375 - categorical_accuracy: 0.8033 - val_loss: 0.3993 - val_categorical_accuracy: 0.8205
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.82220
# Epoch 33/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.4272 - categorical_accuracy: 0.8085 - val_loss: 0.3793 - val_categorical_accuracy: 0.8310
#
# Epoch 00033: val_categorical_accuracy improved from 0.82220 to 0.83100, saving model to best_model.h5
# Epoch 34/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.4153 - categorical_accuracy: 0.8155 - val_loss: 0.3764 - val_categorical_accuracy: 0.8310
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.83100
# Epoch 35/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.4070 - categorical_accuracy: 0.8194 - val_loss: 0.3597 - val_categorical_accuracy: 0.8396
#
# Epoch 00035: val_categorical_accuracy improved from 0.83100 to 0.83960, saving model to best_model.h5
# Epoch 36/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3962 - categorical_accuracy: 0.8250 - val_loss: 0.3527 - val_categorical_accuracy: 0.8445
#
# Epoch 00036: val_categorical_accuracy improved from 0.83960 to 0.84450, saving model to best_model.h5
# Epoch 37/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3863 - categorical_accuracy: 0.8295 - val_loss: 0.3454 - val_categorical_accuracy: 0.8457
#
# Epoch 00037: val_categorical_accuracy improved from 0.84450 to 0.84570, saving model to best_model.h5
# Epoch 38/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3779 - categorical_accuracy: 0.8334 - val_loss: 0.3439 - val_categorical_accuracy: 0.8477
#
# Epoch 00038: val_categorical_accuracy improved from 0.84570 to 0.84770, saving model to best_model.h5
# Epoch 39/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.3694 - categorical_accuracy: 0.8363 - val_loss: 0.3283 - val_categorical_accuracy: 0.8539
#
# Epoch 00039: val_categorical_accuracy improved from 0.84770 to 0.85390, saving model to best_model.h5
# Epoch 40/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3604 - categorical_accuracy: 0.8410 - val_loss: 0.3244 - val_categorical_accuracy: 0.8551
#
# Epoch 00040: val_categorical_accuracy improved from 0.85390 to 0.85510, saving model to best_model.h5
# Epoch 41/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3510 - categorical_accuracy: 0.8459 - val_loss: 0.3146 - val_categorical_accuracy: 0.8610
#
# Epoch 00041: val_categorical_accuracy improved from 0.85510 to 0.86100, saving model to best_model.h5
# Epoch 42/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3451 - categorical_accuracy: 0.8503 - val_loss: 0.3093 - val_categorical_accuracy: 0.8627
#
# Epoch 00042: val_categorical_accuracy improved from 0.86100 to 0.86270, saving model to best_model.h5
# Epoch 43/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3363 - categorical_accuracy: 0.8532 - val_loss: 0.2962 - val_categorical_accuracy: 0.8689
#
# Epoch 00043: val_categorical_accuracy improved from 0.86270 to 0.86890, saving model to best_model.h5
# Epoch 44/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3273 - categorical_accuracy: 0.8571 - val_loss: 0.2976 - val_categorical_accuracy: 0.8674
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.86890
# Epoch 45/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3207 - categorical_accuracy: 0.8614 - val_loss: 0.2914 - val_categorical_accuracy: 0.8701
#
# Epoch 00045: val_categorical_accuracy improved from 0.86890 to 0.87010, saving model to best_model.h5
# Epoch 46/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3148 - categorical_accuracy: 0.8640 - val_loss: 0.2798 - val_categorical_accuracy: 0.8771
#
# Epoch 00046: val_categorical_accuracy improved from 0.87010 to 0.87710, saving model to best_model.h5
# Epoch 47/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3059 - categorical_accuracy: 0.8672 - val_loss: 0.2706 - val_categorical_accuracy: 0.8815
#
# Epoch 00047: val_categorical_accuracy improved from 0.87710 to 0.88150, saving model to best_model.h5
# Epoch 48/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2964 - categorical_accuracy: 0.8720 - val_loss: 0.2699 - val_categorical_accuracy: 0.8812
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.88150
# Epoch 49/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2907 - categorical_accuracy: 0.8741 - val_loss: 0.2607 - val_categorical_accuracy: 0.8873
#
# Epoch 00049: val_categorical_accuracy improved from 0.88150 to 0.88730, saving model to best_model.h5
# Epoch 50/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2829 - categorical_accuracy: 0.8786 - val_loss: 0.2549 - val_categorical_accuracy: 0.8875
#
# Epoch 00050: val_categorical_accuracy improved from 0.88730 to 0.88750, saving model to best_model.h5
# Epoch 51/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.2767 - categorical_accuracy: 0.8827 - val_loss: 0.2629 - val_categorical_accuracy: 0.8846
#
# Epoch 00051: val_categorical_accuracy did not improve from 0.88750
# Epoch 52/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2702 - categorical_accuracy: 0.8856 - val_loss: 0.2421 - val_categorical_accuracy: 0.8975
#
# Epoch 00052: val_categorical_accuracy improved from 0.88750 to 0.89750, saving model to best_model.h5
# Epoch 53/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2674 - categorical_accuracy: 0.8872 - val_loss: 0.2510 - val_categorical_accuracy: 0.8897
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.89750
# Epoch 54/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2619 - categorical_accuracy: 0.8902 - val_loss: 0.2407 - val_categorical_accuracy: 0.8953
#
# Epoch 00054: val_categorical_accuracy did not improve from 0.89750
# Epoch 55/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.2576 - categorical_accuracy: 0.8915 - val_loss: 0.2328 - val_categorical_accuracy: 0.9003
#
# Epoch 00055: val_categorical_accuracy improved from 0.89750 to 0.90030, saving model to best_model.h5
# Epoch 56/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2512 - categorical_accuracy: 0.8943 - val_loss: 0.2370 - val_categorical_accuracy: 0.8960
#
# Epoch 00056: val_categorical_accuracy did not improve from 0.90030
# Epoch 57/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.2456 - categorical_accuracy: 0.8965 - val_loss: 0.2270 - val_categorical_accuracy: 0.9039
#
# Epoch 00057: val_categorical_accuracy improved from 0.90030 to 0.90390, saving model to best_model.h5
# Epoch 58/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2447 - categorical_accuracy: 0.8967 - val_loss: 0.2348 - val_categorical_accuracy: 0.8980
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.90390
# Epoch 59/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2418 - categorical_accuracy: 0.8980 - val_loss: 0.2286 - val_categorical_accuracy: 0.9014
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.90390
# Epoch 60/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2367 - categorical_accuracy: 0.9004 - val_loss: 0.2193 - val_categorical_accuracy: 0.9061
#
# Epoch 00060: val_categorical_accuracy improved from 0.90390 to 0.90610, saving model to best_model.h5
# Epoch 61/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.2313 - categorical_accuracy: 0.9030 - val_loss: 0.2184 - val_categorical_accuracy: 0.9062
#
# Epoch 00061: val_categorical_accuracy improved from 0.90610 to 0.90620, saving model to best_model.h5
# Epoch 62/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2278 - categorical_accuracy: 0.9053 - val_loss: 0.2426 - val_categorical_accuracy: 0.8949
#
# Epoch 00062: val_categorical_accuracy did not improve from 0.90620
# Epoch 63/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.2234 - categorical_accuracy: 0.9063 - val_loss: 0.2127 - val_categorical_accuracy: 0.9090
#
# Epoch 00063: val_categorical_accuracy improved from 0.90620 to 0.90900, saving model to best_model.h5
# Epoch 64/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.2204 - categorical_accuracy: 0.9080 - val_loss: 0.2094 - val_categorical_accuracy: 0.9107
#
# Epoch 00064: val_categorical_accuracy improved from 0.90900 to 0.91070, saving model to best_model.h5
# Epoch 65/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2200 - categorical_accuracy: 0.9076 - val_loss: 0.2036 - val_categorical_accuracy: 0.9137
#
# Epoch 00065: val_categorical_accuracy improved from 0.91070 to 0.91370, saving model to best_model.h5
# Epoch 66/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2156 - categorical_accuracy: 0.9100 - val_loss: 0.2076 - val_categorical_accuracy: 0.9114
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.91370
# Epoch 67/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2135 - categorical_accuracy: 0.9109 - val_loss: 0.2021 - val_categorical_accuracy: 0.9138
#
# Epoch 00067: val_categorical_accuracy improved from 0.91370 to 0.91380, saving model to best_model.h5
# Epoch 68/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.2088 - categorical_accuracy: 0.9143 - val_loss: 0.1987 - val_categorical_accuracy: 0.9150
#
# Epoch 00068: val_categorical_accuracy improved from 0.91380 to 0.91500, saving model to best_model.h5
# Epoch 69/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.2043 - categorical_accuracy: 0.9147 - val_loss: 0.1947 - val_categorical_accuracy: 0.9182
#
# Epoch 00069: val_categorical_accuracy improved from 0.91500 to 0.91820, saving model to best_model.h5
# Epoch 70/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.2052 - categorical_accuracy: 0.9147 - val_loss: 0.1939 - val_categorical_accuracy: 0.9179
#
# Epoch 00070: val_categorical_accuracy did not improve from 0.91820
# Epoch 71/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.2004 - categorical_accuracy: 0.9160 - val_loss: 0.1944 - val_categorical_accuracy: 0.9170
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.91820
# Epoch 72/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1957 - categorical_accuracy: 0.9199 - val_loss: 0.1961 - val_categorical_accuracy: 0.9166
#
# Epoch 00072: val_categorical_accuracy did not improve from 0.91820
# Epoch 73/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1940 - categorical_accuracy: 0.9197 - val_loss: 0.1843 - val_categorical_accuracy: 0.9233
#
# Epoch 00073: val_categorical_accuracy improved from 0.91820 to 0.92330, saving model to best_model.h5
# Epoch 74/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1919 - categorical_accuracy: 0.9208 - val_loss: 0.1876 - val_categorical_accuracy: 0.9213
#
# Epoch 00074: val_categorical_accuracy did not improve from 0.92330
# Epoch 75/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1885 - categorical_accuracy: 0.9235 - val_loss: 0.1902 - val_categorical_accuracy: 0.9209
#
# Epoch 00075: val_categorical_accuracy did not improve from 0.92330
# Epoch 76/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1867 - categorical_accuracy: 0.9239 - val_loss: 0.1811 - val_categorical_accuracy: 0.9253
#
# Epoch 00076: val_categorical_accuracy improved from 0.92330 to 0.92530, saving model to best_model.h5
# Epoch 77/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1816 - categorical_accuracy: 0.9254 - val_loss: 0.1789 - val_categorical_accuracy: 0.9273
#
# Epoch 00077: val_categorical_accuracy improved from 0.92530 to 0.92730, saving model to best_model.h5
# Epoch 78/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1817 - categorical_accuracy: 0.9264 - val_loss: 0.1761 - val_categorical_accuracy: 0.9288
#
# Epoch 00078: val_categorical_accuracy improved from 0.92730 to 0.92880, saving model to best_model.h5
# Epoch 79/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1782 - categorical_accuracy: 0.9270 - val_loss: 0.1696 - val_categorical_accuracy: 0.9317
#
# Epoch 00079: val_categorical_accuracy improved from 0.92880 to 0.93170, saving model to best_model.h5
# Epoch 80/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.1769 - categorical_accuracy: 0.9276 - val_loss: 0.1754 - val_categorical_accuracy: 0.9273
#
# Epoch 00080: val_categorical_accuracy did not improve from 0.93170
# Epoch 81/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1750 - categorical_accuracy: 0.9276 - val_loss: 0.1814 - val_categorical_accuracy: 0.9268
#
# Epoch 00081: val_categorical_accuracy did not improve from 0.93170
# Epoch 82/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1716 - categorical_accuracy: 0.9303 - val_loss: 0.1679 - val_categorical_accuracy: 0.9313
#
# Epoch 00082: val_categorical_accuracy did not improve from 0.93170
# Epoch 83/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1697 - categorical_accuracy: 0.9305 - val_loss: 0.1743 - val_categorical_accuracy: 0.9293
#
# Epoch 00083: val_categorical_accuracy did not improve from 0.93170
# Epoch 84/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1696 - categorical_accuracy: 0.9311 - val_loss: 0.1702 - val_categorical_accuracy: 0.9309
#
# Epoch 00084: val_categorical_accuracy did not improve from 0.93170
# Epoch 85/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1648 - categorical_accuracy: 0.9324 - val_loss: 0.1724 - val_categorical_accuracy: 0.9296
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.93170
# Epoch 86/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1627 - categorical_accuracy: 0.9341 - val_loss: 0.1642 - val_categorical_accuracy: 0.9329
#
# Epoch 00086: val_categorical_accuracy improved from 0.93170 to 0.93290, saving model to best_model.h5
# Epoch 87/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.1599 - categorical_accuracy: 0.9361 - val_loss: 0.1666 - val_categorical_accuracy: 0.9311
#
# Epoch 00087: val_categorical_accuracy did not improve from 0.93290
# Epoch 88/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1601 - categorical_accuracy: 0.9345 - val_loss: 0.1707 - val_categorical_accuracy: 0.9313
#
# Epoch 00088: val_categorical_accuracy did not improve from 0.93290
# Epoch 89/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1582 - categorical_accuracy: 0.9361 - val_loss: 0.1650 - val_categorical_accuracy: 0.9325
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.93290
# Epoch 90/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1581 - categorical_accuracy: 0.9361 - val_loss: 0.1627 - val_categorical_accuracy: 0.9341
#
# Epoch 00090: val_categorical_accuracy improved from 0.93290 to 0.93410, saving model to best_model.h5
# Epoch 91/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1533 - categorical_accuracy: 0.9375 - val_loss: 0.1653 - val_categorical_accuracy: 0.9322
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.93410
# Epoch 92/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1531 - categorical_accuracy: 0.9379 - val_loss: 0.1643 - val_categorical_accuracy: 0.9332
#
# Epoch 00092: val_categorical_accuracy did not improve from 0.93410
# Epoch 93/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1512 - categorical_accuracy: 0.9382 - val_loss: 0.1658 - val_categorical_accuracy: 0.9329
#
# Epoch 00093: val_categorical_accuracy did not improve from 0.93410
# Epoch 94/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1492 - categorical_accuracy: 0.9396 - val_loss: 0.1574 - val_categorical_accuracy: 0.9355
#
# Epoch 00094: val_categorical_accuracy improved from 0.93410 to 0.93550, saving model to best_model.h5
# Epoch 95/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1479 - categorical_accuracy: 0.9398 - val_loss: 0.1624 - val_categorical_accuracy: 0.9358
#
# Epoch 00095: val_categorical_accuracy improved from 0.93550 to 0.93580, saving model to best_model.h5
# Epoch 96/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1452 - categorical_accuracy: 0.9408 - val_loss: 0.1594 - val_categorical_accuracy: 0.9347
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.93580
# Epoch 97/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1454 - categorical_accuracy: 0.9412 - val_loss: 0.1556 - val_categorical_accuracy: 0.9365
#
# Epoch 00097: val_categorical_accuracy improved from 0.93580 to 0.93650, saving model to best_model.h5
# Epoch 98/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1440 - categorical_accuracy: 0.9421 - val_loss: 0.1629 - val_categorical_accuracy: 0.9342
#
# Epoch 00098: val_categorical_accuracy did not improve from 0.93650
# Epoch 99/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1410 - categorical_accuracy: 0.9423 - val_loss: 0.1602 - val_categorical_accuracy: 0.9350
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.93650
# Epoch 100/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1424 - categorical_accuracy: 0.9411 - val_loss: 0.1637 - val_categorical_accuracy: 0.9352
#
# Epoch 00100: val_categorical_accuracy did not improve from 0.93650
# Epoch 101/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1363 - categorical_accuracy: 0.9449 - val_loss: 0.1624 - val_categorical_accuracy: 0.9333
#
# Epoch 00101: val_categorical_accuracy did not improve from 0.93650
# Epoch 102/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1358 - categorical_accuracy: 0.9458 - val_loss: 0.1635 - val_categorical_accuracy: 0.9353
#
# Epoch 00102: val_categorical_accuracy did not improve from 0.93650
# Epoch 103/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1365 - categorical_accuracy: 0.9446 - val_loss: 0.1582 - val_categorical_accuracy: 0.9350
#
# Epoch 00103: val_categorical_accuracy did not improve from 0.93650
# Epoch 104/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1333 - categorical_accuracy: 0.9461 - val_loss: 0.1553 - val_categorical_accuracy: 0.9369
#
# Epoch 00104: val_categorical_accuracy improved from 0.93650 to 0.93690, saving model to best_model.h5
# Epoch 105/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.1347 - categorical_accuracy: 0.9451 - val_loss: 0.1572 - val_categorical_accuracy: 0.9359
#
# Epoch 00105: val_categorical_accuracy did not improve from 0.93690
# Epoch 106/256
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.1319 - categorical_accuracy: 0.9467 - val_loss: 0.1561 - val_categorical_accuracy: 0.9377
#
# Epoch 00106: val_categorical_accuracy improved from 0.93690 to 0.93770, saving model to best_model.h5
# Epoch 107/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1313 - categorical_accuracy: 0.9473 - val_loss: 0.1542 - val_categorical_accuracy: 0.9374
#
# Epoch 00107: val_categorical_accuracy did not improve from 0.93770
# Epoch 108/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.1305 - categorical_accuracy: 0.9475 - val_loss: 0.1548 - val_categorical_accuracy: 0.9381
#
# Epoch 00108: val_categorical_accuracy improved from 0.93770 to 0.93810, saving model to best_model.h5
# Epoch 109/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.1279 - categorical_accuracy: 0.9484 - val_loss: 0.1571 - val_categorical_accuracy: 0.9383
#
# Epoch 00109: val_categorical_accuracy improved from 0.93810 to 0.93830, saving model to best_model.h5
# Epoch 110/256
# 60000/60000 [==============================] - 20s 342us/step - loss: 0.1265 - categorical_accuracy: 0.9499 - val_loss: 0.1612 - val_categorical_accuracy: 0.9367
#
# Epoch 00110: val_categorical_accuracy did not improve from 0.93830
# Epoch 111/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1265 - categorical_accuracy: 0.9492 - val_loss: 0.1606 - val_categorical_accuracy: 0.9378
#
# Epoch 00111: val_categorical_accuracy did not improve from 0.93830
# Epoch 112/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1224 - categorical_accuracy: 0.9498 - val_loss: 0.1535 - val_categorical_accuracy: 0.9389
#
# Epoch 00112: val_categorical_accuracy improved from 0.93830 to 0.93890, saving model to best_model.h5
# Epoch 113/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1237 - categorical_accuracy: 0.9506 - val_loss: 0.1517 - val_categorical_accuracy: 0.9385
#
# Epoch 00113: val_categorical_accuracy did not improve from 0.93890
# Epoch 114/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1241 - categorical_accuracy: 0.9499 - val_loss: 0.1543 - val_categorical_accuracy: 0.9388
#
# Epoch 00114: val_categorical_accuracy did not improve from 0.93890
# Epoch 115/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1228 - categorical_accuracy: 0.9508 - val_loss: 0.1516 - val_categorical_accuracy: 0.9383
#
# Epoch 00115: val_categorical_accuracy did not improve from 0.93890
# Epoch 116/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1194 - categorical_accuracy: 0.9517 - val_loss: 0.1518 - val_categorical_accuracy: 0.9392
#
# Epoch 00116: val_categorical_accuracy improved from 0.93890 to 0.93920, saving model to best_model.h5
# Epoch 117/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1201 - categorical_accuracy: 0.9519 - val_loss: 0.1584 - val_categorical_accuracy: 0.9380
#
# Epoch 00117: val_categorical_accuracy did not improve from 0.93920
# Epoch 118/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.1163 - categorical_accuracy: 0.9533 - val_loss: 0.1515 - val_categorical_accuracy: 0.9393
#
# Epoch 00118: val_categorical_accuracy improved from 0.93920 to 0.93930, saving model to best_model.h5
# Epoch 119/256
# 60000/60000 [==============================] - 19s 325us/step - loss: 0.1150 - categorical_accuracy: 0.9540 - val_loss: 0.1509 - val_categorical_accuracy: 0.9412
#
# Epoch 00119: val_categorical_accuracy improved from 0.93930 to 0.94120, saving model to best_model.h5
# Epoch 120/256
# 60000/60000 [==============================] - 19s 324us/step - loss: 0.1156 - categorical_accuracy: 0.9537 - val_loss: 0.1580 - val_categorical_accuracy: 0.9398
#
# Epoch 00120: val_categorical_accuracy did not improve from 0.94120
# Epoch 121/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.1147 - categorical_accuracy: 0.9536 - val_loss: 0.1504 - val_categorical_accuracy: 0.9423
#
# Epoch 00121: val_categorical_accuracy improved from 0.94120 to 0.94230, saving model to best_model.h5
# Epoch 122/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1105 - categorical_accuracy: 0.9560 - val_loss: 0.1523 - val_categorical_accuracy: 0.9415
#
# Epoch 00122: val_categorical_accuracy did not improve from 0.94230
# Epoch 123/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1137 - categorical_accuracy: 0.9553 - val_loss: 0.1506 - val_categorical_accuracy: 0.9413
#
# Epoch 00123: val_categorical_accuracy did not improve from 0.94230
# Epoch 124/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1103 - categorical_accuracy: 0.9557 - val_loss: 0.1511 - val_categorical_accuracy: 0.9411
#
# Epoch 00124: val_categorical_accuracy did not improve from 0.94230
# Epoch 125/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1107 - categorical_accuracy: 0.9556 - val_loss: 0.1533 - val_categorical_accuracy: 0.9404
#
# Epoch 00125: val_categorical_accuracy did not improve from 0.94230
# Epoch 126/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.1088 - categorical_accuracy: 0.9565 - val_loss: 0.1501 - val_categorical_accuracy: 0.9415
#
# Epoch 00126: val_categorical_accuracy did not improve from 0.94230
# Epoch 127/256
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.1068 - categorical_accuracy: 0.9590 - val_loss: 0.1520 - val_categorical_accuracy: 0.9406
#
# Epoch 00127: val_categorical_accuracy did not improve from 0.94230
# Epoch 128/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1056 - categorical_accuracy: 0.9578 - val_loss: 0.1525 - val_categorical_accuracy: 0.9411
#
# Epoch 00128: val_categorical_accuracy did not improve from 0.94230
# Epoch 129/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.1062 - categorical_accuracy: 0.9578 - val_loss: 0.1574 - val_categorical_accuracy: 0.9397
#
# Epoch 00129: val_categorical_accuracy did not improve from 0.94230
# Epoch 130/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.1048 - categorical_accuracy: 0.9583 - val_loss: 0.1552 - val_categorical_accuracy: 0.9402
#
# Epoch 00130: val_categorical_accuracy did not improve from 0.94230
# Epoch 131/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.1038 - categorical_accuracy: 0.9584 - val_loss: 0.1638 - val_categorical_accuracy: 0.9391
#
# Epoch 00131: val_categorical_accuracy did not improve from 0.94230
# Epoch 00131: early stopping

# %%
# evaluate loaded model
scores_train = saved_model.evaluate(xx_train, yy_train, verbose=0)
scores_test  = saved_model.evaluate(xx_test,  yy_test,  verbose=0)
scores_val   = saved_model.evaluate(xx_val,   yy_val,   verbose=0)
print("Accuracy Train: %.2f%% , Test: %.2f%% Val: %.2f%% " % (scores_train[1]*100, scores_test[1]*100, scores_val[1]*100))
# Out:
# Accuracy Train: 97.99% , Test: 94.23% Val: 94.25%

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(cnn.history['loss'])

plt.figure(0)
plt.plot(cnn.history['categorical_accuracy'],'r')
plt.plot(cnn.history['val_categorical_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

plt.figure(1)
plt.plot(cnn.history['loss'],'r')
plt.plot(cnn.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
YY_pred = saved_model.predict(xx_val, verbose=2)
yy_pred = np.argmax(YY_pred, axis=2)

yy_test2 = np.argmax(yy_test, axis=2)



#confusion matrix
cm = confusion_matrix(np.argmax(yy_val,axis=2),yy_pred)
print(cm)

# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(num_classes),
                  range(num_classes))
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()
# Out:
# [[3310   16    1]
#  [  42 2985  292]
#  [   1  223 3130]]

# %%
def plot_results(plot_size=6):
  
  offset = max(0, min(len(YY_pred)-plot_size*plot_size, np.random.randint(0,len(YY_pred)/2)))

  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for i in range(min(plot_size/2,len(YY_pred)/plot_size)):
    for n in range(min(plot_size,len(YY_pred))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+n+1 )
      ax.imshow(xx_val[plot_size*i+n+offset,0])
      ax.axis('off')

    for n in range(min(plot_size,len(YY_pred))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+plot_size+n+1)
      x = np.arange(3)
      ax.bar(x, height = YY_pred[plot_size*i+n+offset,0], tick_label = class_names) 
      ax.axis('off')
#      ax.set_title(class_names[int(np.argmax(YY_pred,axis=2)[plot_size*i+n+offset])])
      ax.set_title(class_names[int(np.argmax(yy_val,axis=2)[plot_size*i+n+offset])])
#      print("yy_val",np.argmax(yy_val,axis=2))
#      print("YY_pred",np.argmax(YY_pred,axis=2))
  
  plt.show()
  #plt.savefig('event.png')
  #plt.clf()


plot_results(6)
plot_results(6)
plot_results(6)
plot_results(6)
plot_results(6)

plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
