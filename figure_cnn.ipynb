# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/DNN_examples/blob/master/figure_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple convnet on the generated set of figures (circle, triangle, square)
'''
from __future__ import print_function


# !pip install keras_sequential_ascii

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Reshape
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation
from keras import backend as K
from keras_sequential_ascii import sequential_model_to_ascii_printout
from keras.utils import plot_model
from keras.utils import np_utils
from keras.optimizers import SGD
from keras.constraints import maxnorm
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras import metrics

from PIL import Image, ImageDraw

import time
import math
# Out:
# Collecting keras_sequential_ascii
#   Downloading https://files.pythonhosted.org/packages/2d/a4/806e3ed5d7ac7463e2fae77e09ccccc88c78266b248fb637e4efa4f65ec0/keras_sequential_ascii-0.1.1.tar.gz
# Requirement already satisfied: keras in /usr/local/lib/python2.7/dist-packages (from keras_sequential_ascii) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.16.4)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (2.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.2.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (3.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from keras->keras_sequential_ascii) (1.12.0)
# Building wheels for collected packages: keras-sequential-ascii
#   Building wheel for keras-sequential-ascii (setup.py) ... done
#   Created wheel for keras-sequential-ascii: filename=keras_sequential_ascii-0.1.1-cp27-none-any.whl size=3062 sha256=aad48de6c6028c63d69a8334fbda33de8c169ca098e02ea41365727d1e875191
#   Stored in directory: /root/.cache/pip/wheels/f5/8d/81/912666dff82a923ce423a7e797cd75f54271c7031512cdb282
# Successfully built keras-sequential-ascii
# Installing collected packages: keras-sequential-ascii
# Successfully installed keras-sequential-ascii-0.1.1
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
batch_size = 128
num_classes = 3
epochs = 256 #12

np.random.seed(2348)

batch_size_gen = 60000
batch_size_val = 10000

# input image dimensions
img_rows, img_cols = 32, 32
img_shape = (img_rows, img_cols)


#probability of noise and the efficiency<1
prob_noise = 0.50

# %%
def gen_noise(batch_size_gen=batch_size_gen, img_shape=img_shape, prob_noise=prob_noise):

        batch_events = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        for n in range(batch_size_gen):

            for i in range(img_shape[0]):
               for j in range(img_shape[1]):
                 if np.random.random()<prob_noise:
                     batch_events[n,0,i,j]=1


        yield batch_events

# %%
### generate geometrical figures

def generate_circle(r, x0, y0, img_shape):
    """
    Generate a single circle.
    Parameters:
        r: radius
        x0,y0: position of the circle center
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.ellipse((x0-r, y0-r, x0+r, y0+r), outline ='white')
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
def generate_square(d, x0, y0, angle, img_shape):
    """
    Generate a square.
    Parameters:
        d: size
        x0,y0: position of the square center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    draw.rectangle((x0-d/2, y0-d/2, x0+d/2, y0+d/2), outline ='white')
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
def generate_triangle(d, x0, y0, angle, img_shape):
    """
    Generate a square.
    Parameters:
        d: size 
        x0,y0: position of the square center
        angle: rotation angle
        img_shape: image shape (depth, width)
    Returns:
        ndarray data for one figure.
    """

    image = Image.new('1', img_shape) #create new image, 10x10 pixels, 1 bit per pixel
    draw = ImageDraw.Draw(image)
    dd = d/math.sqrt(3)
    draw.polygon(((x0-d/2, y0-dd/2), (x0+d/2, y0-dd/2), (x0,y0+dd)), outline ='white')
    image = image.rotate(angle)
    #print(list(image.getdata()))
    #image.show()
    x = np.array(image).astype('int')
    
    #print(x)
    return x

# %%
# generate a random number
def rand_interval(a = 0., b = 1.):
   rnd = a + (b-a)*np.random.random()
   return rnd

# %%
# Generator for random figures
# Each image contains exactly one object (circle, triangle, square)
def gen_n_figures(batch_size_gen=batch_size_gen, img_shape=img_shape):

        batch_events  = np.zeros((batch_size_gen, 1, img_shape[0], img_shape[1]))
        batch_targets =-np.ones((batch_size_gen, 1, 1 ))

        for n in range(batch_size_gen):
            
            k = np.random.randint(0,3)
            
            r = rand_interval(img_cols*0.15, img_cols*0.5)
            d = rand_interval(img_cols*0.15, img_cols*0.7) 
            l = rand_interval(img_cols*0.15, img_cols*0.7)
            x0 = rand_interval(0.33*img_cols, 0.66*img_cols)       
            y0 = rand_interval(0.33*img_rows, 0.66*img_rows)     
            alpha = 360.*np.random.random()  

            if k == 0:
               batch_events[n,0] = generate_circle(r, x0, y0, img_shape)
            elif k == 1:
               batch_events[n,0] = generate_square(d, x0, y0, alpha, img_shape)
            elif k == 2:
               batch_events[n,0] = generate_triangle(l, x0, y0, alpha, img_shape)
            else:
               print("Wrong figure id!!!")
            batch_targets[n,0] = k
            


        yield batch_events, batch_targets

# %%
#generate training and validation dataset
xx_train, yy_train = gen_n_figures(batch_size_gen, img_shape).next()
xx_test, yy_test   = gen_n_figures(batch_size_val, img_shape).next()
xx_val, yy_val     = gen_n_figures(batch_size_val, img_shape).next()


# add noise
xx_train = xx_train + gen_noise(batch_size_gen, img_shape).next()
xx_test  = xx_test  + gen_noise(batch_size_val, img_shape).next()
xx_val   = xx_val  + gen_noise(batch_size_val, img_shape).next()

#and clip to get maximum 1
xx_train = np.clip(xx_train, 0, 1)
xx_test  = np.clip(xx_test, 0, 1)
xx_val   = np.clip(xx_val, 0, 1)

# %%
#plot 100 figures (random offset)
class_names = ['circle','square','triangle']


def plot_images(plot_size=6):
  offset = max(0, min(batch_size_gen-plot_size*plot_size, np.random.randint(0,batch_size_gen/2)))
  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for n in range(min(plot_size*plot_size,len(xx_train))):
    ax = plt.subplot(plot_size, plot_size, n+1)
    ax.imshow(xx_train[n+offset,0])
    ax.set_title(class_names[int(yy_train[n+offset,0])])
    ax.axis('off')

  plt.show()
  #plt.savefig('event.png')
  #plt.clf()
  
plot_images(6)
plot_images(6)
plot_images(6)
plot_images(2)
plot_images(2)
plot_images(2)
plot_images(2)

# %%
# Convert and pre-processing

yy_train = np_utils.to_categorical(yy_train, num_classes)
yy_test = np_utils.to_categorical(yy_test, num_classes)
yy_val = np_utils.to_categorical(yy_val, num_classes)

print("yy_train ",yy_train.shape)
# Out:
# yy_train  (60000, 1, 3)

# %%
# Define Model

def base_model():

    model = Sequential()
    input_shape=(1,img_rows,img_cols)

    model.add(Reshape((img_rows,img_cols,1),input_shape=input_shape))


    model.add(Conv2D(img_rows, (3, 3), padding='same', activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(img_rows,(3,3),padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(2*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(Dropout(rate = 0.2))

    model.add(Conv2D(4*img_rows,(3,3),padding='same',activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Flatten())
    model.add(Dropout(rate = 0.2))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))
    model.add(Dense(32*img_rows,activation='relu',kernel_constraint=maxnorm(3))) #1024
    model.add(Dropout(rate = 0.3))


    model.add(Dense(num_classes, activation='softmax'))

    model.add(Reshape((1,num_classes),input_shape=(num_classes,)))

#    sgd = SGD(lr = 0.1, decay=1e-6, nesterov=True)
    sgd = SGD(lr = 0.01, decay=1e-6, nesterov=True)

# Train model

    model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=[metrics.categorical_accuracy])   # 'accuracy'
    return model

# %%
# Vizualizing model structure
# Model summary (ascii)
cnn_n = base_model()
cnn_n.summary()

# Model printout (ascii)
sequential_model_to_ascii_printout(cnn_n)

# Plotting model in graphical mode
plot_model(cnn_n)   ###, to_file='model.png')  ###, show_shapes=True
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1119 09:07:59.063486 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W1119 09:07:59.074279 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1119 09:07:59.091567 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W1119 09:07:59.119760 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W1119 09:07:59.132507 140421322692480 deprecation.py:506] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W1119 09:07:59.158246 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W1119 09:07:59.350193 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W1119 09:07:59.360872 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 3075
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1, 3)              0
# =================================================================
# Total params: 3,437,283
# Trainable params: 3,437,283
# Non-trainable params: 0
# _________________________________________________________________
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####      1   32   32
#              Reshape     |   -------------------         0     0.0%
#                        #####     32   32    1
#               Conv2D    \|/  -------------------       320     0.0%
#                 relu   #####     32   32   32
#              Dropout    | || -------------------         0     0.0%
#                        #####     32   32   32
#               Conv2D    \|/  -------------------      9248     0.0%
#                 relu   #####     32   32   32
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####     16   16   32
#               Conv2D    \|/  -------------------     18496     0.0%
#                 relu   #####     16   16   64
#              Dropout    | || -------------------         0     0.0%
#                        #####     16   16   64
#               Conv2D    \|/  -------------------     36928     1.0%
#                 relu   #####     16   16   64
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      8    8   64
#               Conv2D    \|/  -------------------     73856     2.0%
#                 relu   #####      8    8  128
#              Dropout    | || -------------------         0     0.0%
#                        #####      8    8  128
#               Conv2D    \|/  -------------------    147584     4.0%
#                 relu   #####      8    8  128
#         MaxPooling2D   Y max -------------------         0     0.0%
#                        #####      4    4  128
#              Flatten   ||||| -------------------         0     0.0%
#                        #####        2048
#              Dropout    | || -------------------         0     0.0%
#                        #####        2048
#                Dense   XXXXX -------------------   2098176    61.0%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------   1049600    30.0%
#                 relu   #####        1024
#              Dropout    | || -------------------         0     0.0%
#                        #####        1024
#                Dense   XXXXX -------------------      3075     0.0%
#              softmax   #####           3
#              Reshape     |   -------------------         0     0.0%
#                        #####      1    3

# %%
# patient early stopping
es = EarlyStopping(monitor='val_categorical_accuracy', mode='max', verbose=1, patience=10)
mc = ModelCheckpoint('best_model.h5', monitor='val_categorical_accuracy', mode='max', verbose=1, save_best_only=True)
# fit model
cnn = cnn_n.fit(xx_train, yy_train, batch_size=batch_size, epochs=epochs, validation_data=(xx_test,yy_test),shuffle=True, callbacks=[es, mc])
# load the saved model
saved_model = load_model('best_model.h5')
# Out:
# W1119 09:07:59.818610 140421322692480 deprecation.py:323] From /usr/local/lib/python2.7/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1119 09:08:00.122118 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1119 09:08:00.193115 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W1119 09:08:00.305747 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1119 09:08:00.313819 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W1119 09:08:00.314899 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/256
# W1119 09:08:01.648139 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# W1119 09:08:01.650130 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# W1119 09:08:01.796610 140421322692480 module_wrapper.py:139] From /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# 60000/60000 [==============================] - 27s 456us/step - loss: 1.0994 - categorical_accuracy: 0.3347 - val_loss: 1.0986 - val_categorical_accuracy: 0.3373
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.33730, saving model to best_model.h5
# Epoch 2/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 1.0988 - categorical_accuracy: 0.3361 - val_loss: 1.0985 - val_categorical_accuracy: 0.3346
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.33730
# Epoch 3/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.0987 - categorical_accuracy: 0.3365 - val_loss: 1.0984 - val_categorical_accuracy: 0.3449
#
# Epoch 00003: val_categorical_accuracy improved from 0.33730 to 0.34490, saving model to best_model.h5
# Epoch 4/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.0985 - categorical_accuracy: 0.3417 - val_loss: 1.0983 - val_categorical_accuracy: 0.3346
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.34490
# Epoch 5/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 1.0982 - categorical_accuracy: 0.3452 - val_loss: 1.0982 - val_categorical_accuracy: 0.3346
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.34490
# Epoch 6/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 1.0978 - categorical_accuracy: 0.3522 - val_loss: 1.0976 - val_categorical_accuracy: 0.3346
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.34490
# Epoch 7/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 1.0967 - categorical_accuracy: 0.3644 - val_loss: 1.0966 - val_categorical_accuracy: 0.3346
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.34490
# Epoch 8/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.0946 - categorical_accuracy: 0.3762 - val_loss: 1.0939 - val_categorical_accuracy: 0.3346
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.34490
# Epoch 9/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 1.0859 - categorical_accuracy: 0.4044 - val_loss: 1.0732 - val_categorical_accuracy: 0.4586
#
# Epoch 00009: val_categorical_accuracy improved from 0.34490 to 0.45860, saving model to best_model.h5
# Epoch 10/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 1.0385 - categorical_accuracy: 0.4533 - val_loss: 0.9822 - val_categorical_accuracy: 0.4988
#
# Epoch 00010: val_categorical_accuracy improved from 0.45860 to 0.49880, saving model to best_model.h5
# Epoch 11/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.9948 - categorical_accuracy: 0.4874 - val_loss: 0.9860 - val_categorical_accuracy: 0.5074
#
# Epoch 00011: val_categorical_accuracy improved from 0.49880 to 0.50740, saving model to best_model.h5
# Epoch 12/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.9800 - categorical_accuracy: 0.4993 - val_loss: 0.9516 - val_categorical_accuracy: 0.5206
#
# Epoch 00012: val_categorical_accuracy improved from 0.50740 to 0.52060, saving model to best_model.h5
# Epoch 13/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.9725 - categorical_accuracy: 0.5000 - val_loss: 1.0024 - val_categorical_accuracy: 0.4882
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.52060
# Epoch 14/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.9626 - categorical_accuracy: 0.5099 - val_loss: 0.9822 - val_categorical_accuracy: 0.4976
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.52060
# Epoch 15/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.9518 - categorical_accuracy: 0.5147 - val_loss: 0.9258 - val_categorical_accuracy: 0.5347
#
# Epoch 00015: val_categorical_accuracy improved from 0.52060 to 0.53470, saving model to best_model.h5
# Epoch 16/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.9412 - categorical_accuracy: 0.5218 - val_loss: 0.9162 - val_categorical_accuracy: 0.5460
#
# Epoch 00016: val_categorical_accuracy improved from 0.53470 to 0.54600, saving model to best_model.h5
# Epoch 17/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.9299 - categorical_accuracy: 0.5267 - val_loss: 0.9040 - val_categorical_accuracy: 0.5540
#
# Epoch 00017: val_categorical_accuracy improved from 0.54600 to 0.55400, saving model to best_model.h5
# Epoch 18/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.9219 - categorical_accuracy: 0.5316 - val_loss: 0.8898 - val_categorical_accuracy: 0.5594
#
# Epoch 00018: val_categorical_accuracy improved from 0.55400 to 0.55940, saving model to best_model.h5
# Epoch 19/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.9103 - categorical_accuracy: 0.5397 - val_loss: 0.8781 - val_categorical_accuracy: 0.5643
#
# Epoch 00019: val_categorical_accuracy improved from 0.55940 to 0.56430, saving model to best_model.h5
# Epoch 20/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.8977 - categorical_accuracy: 0.5485 - val_loss: 0.8682 - val_categorical_accuracy: 0.5724
#
# Epoch 00020: val_categorical_accuracy improved from 0.56430 to 0.57240, saving model to best_model.h5
# Epoch 21/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.8859 - categorical_accuracy: 0.5583 - val_loss: 0.8525 - val_categorical_accuracy: 0.5836
#
# Epoch 00021: val_categorical_accuracy improved from 0.57240 to 0.58360, saving model to best_model.h5
# Epoch 22/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.8723 - categorical_accuracy: 0.5675 - val_loss: 0.9061 - val_categorical_accuracy: 0.5465
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.58360
# Epoch 23/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.8606 - categorical_accuracy: 0.5735 - val_loss: 0.8242 - val_categorical_accuracy: 0.6048
#
# Epoch 00023: val_categorical_accuracy improved from 0.58360 to 0.60480, saving model to best_model.h5
# Epoch 24/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.8456 - categorical_accuracy: 0.5856 - val_loss: 0.8097 - val_categorical_accuracy: 0.6101
#
# Epoch 00024: val_categorical_accuracy improved from 0.60480 to 0.61010, saving model to best_model.h5
# Epoch 25/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.8328 - categorical_accuracy: 0.5922 - val_loss: 0.7957 - val_categorical_accuracy: 0.6201
#
# Epoch 00025: val_categorical_accuracy improved from 0.61010 to 0.62010, saving model to best_model.h5
# Epoch 26/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.8155 - categorical_accuracy: 0.6041 - val_loss: 0.8214 - val_categorical_accuracy: 0.5971
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.62010
# Epoch 27/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.8000 - categorical_accuracy: 0.6133 - val_loss: 0.7542 - val_categorical_accuracy: 0.6417
#
# Epoch 00027: val_categorical_accuracy improved from 0.62010 to 0.64170, saving model to best_model.h5
# Epoch 28/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.7827 - categorical_accuracy: 0.6232 - val_loss: 0.7565 - val_categorical_accuracy: 0.6360
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.64170
# Epoch 29/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.7668 - categorical_accuracy: 0.6311 - val_loss: 0.7205 - val_categorical_accuracy: 0.6576
#
# Epoch 00029: val_categorical_accuracy improved from 0.64170 to 0.65760, saving model to best_model.h5
# Epoch 30/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.7513 - categorical_accuracy: 0.6407 - val_loss: 0.7170 - val_categorical_accuracy: 0.6546
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.65760
# Epoch 31/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.7367 - categorical_accuracy: 0.6469 - val_loss: 0.6899 - val_categorical_accuracy: 0.6741
#
# Epoch 00031: val_categorical_accuracy improved from 0.65760 to 0.67410, saving model to best_model.h5
# Epoch 32/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.7235 - categorical_accuracy: 0.6561 - val_loss: 0.6985 - val_categorical_accuracy: 0.6632
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.67410
# Epoch 33/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.7123 - categorical_accuracy: 0.6595 - val_loss: 0.6636 - val_categorical_accuracy: 0.6878
#
# Epoch 00033: val_categorical_accuracy improved from 0.67410 to 0.68780, saving model to best_model.h5
# Epoch 34/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.6981 - categorical_accuracy: 0.6702 - val_loss: 0.6602 - val_categorical_accuracy: 0.6848
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.68780
# Epoch 35/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.6839 - categorical_accuracy: 0.6765 - val_loss: 0.6356 - val_categorical_accuracy: 0.7019
#
# Epoch 00035: val_categorical_accuracy improved from 0.68780 to 0.70190, saving model to best_model.h5
# Epoch 36/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.6690 - categorical_accuracy: 0.6838 - val_loss: 0.6381 - val_categorical_accuracy: 0.6993
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.70190
# Epoch 37/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.6556 - categorical_accuracy: 0.6911 - val_loss: 0.6101 - val_categorical_accuracy: 0.7123
#
# Epoch 00037: val_categorical_accuracy improved from 0.70190 to 0.71230, saving model to best_model.h5
# Epoch 38/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.6411 - categorical_accuracy: 0.7006 - val_loss: 0.5990 - val_categorical_accuracy: 0.7187
#
# Epoch 00038: val_categorical_accuracy improved from 0.71230 to 0.71870, saving model to best_model.h5
# Epoch 39/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.6300 - categorical_accuracy: 0.7045 - val_loss: 0.5945 - val_categorical_accuracy: 0.7202
#
# Epoch 00039: val_categorical_accuracy improved from 0.71870 to 0.72020, saving model to best_model.h5
# Epoch 40/256
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.6198 - categorical_accuracy: 0.7112 - val_loss: 0.5734 - val_categorical_accuracy: 0.7330
#
# Epoch 00040: val_categorical_accuracy improved from 0.72020 to 0.73300, saving model to best_model.h5
# Epoch 41/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.6103 - categorical_accuracy: 0.7151 - val_loss: 0.5669 - val_categorical_accuracy: 0.7379
#
# Epoch 00041: val_categorical_accuracy improved from 0.73300 to 0.73790, saving model to best_model.h5
# Epoch 42/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5996 - categorical_accuracy: 0.7198 - val_loss: 0.5621 - val_categorical_accuracy: 0.7382
#
# Epoch 00042: val_categorical_accuracy improved from 0.73790 to 0.73820, saving model to best_model.h5
# Epoch 43/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.5904 - categorical_accuracy: 0.7257 - val_loss: 0.5499 - val_categorical_accuracy: 0.7472
#
# Epoch 00043: val_categorical_accuracy improved from 0.73820 to 0.74720, saving model to best_model.h5
# Epoch 44/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5810 - categorical_accuracy: 0.7278 - val_loss: 0.5424 - val_categorical_accuracy: 0.7487
#
# Epoch 00044: val_categorical_accuracy improved from 0.74720 to 0.74870, saving model to best_model.h5
# Epoch 45/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5738 - categorical_accuracy: 0.7327 - val_loss: 0.5349 - val_categorical_accuracy: 0.7534
#
# Epoch 00045: val_categorical_accuracy improved from 0.74870 to 0.75340, saving model to best_model.h5
# Epoch 46/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5679 - categorical_accuracy: 0.7352 - val_loss: 0.5266 - val_categorical_accuracy: 0.7531
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.75340
# Epoch 47/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.5568 - categorical_accuracy: 0.7389 - val_loss: 0.5276 - val_categorical_accuracy: 0.7521
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.75340
# Epoch 48/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.5471 - categorical_accuracy: 0.7441 - val_loss: 0.5135 - val_categorical_accuracy: 0.7611
#
# Epoch 00048: val_categorical_accuracy improved from 0.75340 to 0.76110, saving model to best_model.h5
# Epoch 49/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.5402 - categorical_accuracy: 0.7480 - val_loss: 0.5177 - val_categorical_accuracy: 0.7559
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.76110
# Epoch 50/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.5348 - categorical_accuracy: 0.7514 - val_loss: 0.5098 - val_categorical_accuracy: 0.7596
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.76110
# Epoch 51/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5263 - categorical_accuracy: 0.7538 - val_loss: 0.4978 - val_categorical_accuracy: 0.7643
#
# Epoch 00051: val_categorical_accuracy improved from 0.76110 to 0.76430, saving model to best_model.h5
# Epoch 52/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5200 - categorical_accuracy: 0.7560 - val_loss: 0.4862 - val_categorical_accuracy: 0.7699
#
# Epoch 00052: val_categorical_accuracy improved from 0.76430 to 0.76990, saving model to best_model.h5
# Epoch 53/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.5142 - categorical_accuracy: 0.7591 - val_loss: 0.4897 - val_categorical_accuracy: 0.7657
#
# Epoch 00053: val_categorical_accuracy did not improve from 0.76990
# Epoch 54/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5089 - categorical_accuracy: 0.7632 - val_loss: 0.4751 - val_categorical_accuracy: 0.7748
#
# Epoch 00054: val_categorical_accuracy improved from 0.76990 to 0.77480, saving model to best_model.h5
# Epoch 55/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.5013 - categorical_accuracy: 0.7662 - val_loss: 0.4746 - val_categorical_accuracy: 0.7745
#
# Epoch 00055: val_categorical_accuracy did not improve from 0.77480
# Epoch 56/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4951 - categorical_accuracy: 0.7702 - val_loss: 0.4692 - val_categorical_accuracy: 0.7765
#
# Epoch 00056: val_categorical_accuracy improved from 0.77480 to 0.77650, saving model to best_model.h5
# Epoch 57/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4896 - categorical_accuracy: 0.7714 - val_loss: 0.4609 - val_categorical_accuracy: 0.7835
#
# Epoch 00057: val_categorical_accuracy improved from 0.77650 to 0.78350, saving model to best_model.h5
# Epoch 58/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.4853 - categorical_accuracy: 0.7746 - val_loss: 0.4598 - val_categorical_accuracy: 0.7806
#
# Epoch 00058: val_categorical_accuracy did not improve from 0.78350
# Epoch 59/256
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.4804 - categorical_accuracy: 0.7776 - val_loss: 0.4621 - val_categorical_accuracy: 0.7797
#
# Epoch 00059: val_categorical_accuracy did not improve from 0.78350
# Epoch 60/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4741 - categorical_accuracy: 0.7789 - val_loss: 0.4501 - val_categorical_accuracy: 0.7860
#
# Epoch 00060: val_categorical_accuracy improved from 0.78350 to 0.78600, saving model to best_model.h5
# Epoch 61/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4695 - categorical_accuracy: 0.7802 - val_loss: 0.4448 - val_categorical_accuracy: 0.7884
#
# Epoch 00061: val_categorical_accuracy improved from 0.78600 to 0.78840, saving model to best_model.h5
# Epoch 62/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4658 - categorical_accuracy: 0.7821 - val_loss: 0.4417 - val_categorical_accuracy: 0.7892
#
# Epoch 00062: val_categorical_accuracy improved from 0.78840 to 0.78920, saving model to best_model.h5
# Epoch 63/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4617 - categorical_accuracy: 0.7858 - val_loss: 0.4356 - val_categorical_accuracy: 0.7932
#
# Epoch 00063: val_categorical_accuracy improved from 0.78920 to 0.79320, saving model to best_model.h5
# Epoch 64/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4535 - categorical_accuracy: 0.7901 - val_loss: 0.4411 - val_categorical_accuracy: 0.7894
#
# Epoch 00064: val_categorical_accuracy did not improve from 0.79320
# Epoch 65/256
# 60000/60000 [==============================] - 19s 316us/step - loss: 0.4504 - categorical_accuracy: 0.7903 - val_loss: 0.4248 - val_categorical_accuracy: 0.7964
#
# Epoch 00065: val_categorical_accuracy improved from 0.79320 to 0.79640, saving model to best_model.h5
# Epoch 66/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.4470 - categorical_accuracy: 0.7923 - val_loss: 0.4285 - val_categorical_accuracy: 0.7945
#
# Epoch 00066: val_categorical_accuracy did not improve from 0.79640
# Epoch 67/256
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.4414 - categorical_accuracy: 0.7951 - val_loss: 0.4200 - val_categorical_accuracy: 0.8026
#
# Epoch 00067: val_categorical_accuracy improved from 0.79640 to 0.80260, saving model to best_model.h5
# Epoch 68/256
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.4384 - categorical_accuracy: 0.7983 - val_loss: 0.4182 - val_categorical_accuracy: 0.7997
#
# Epoch 00068: val_categorical_accuracy did not improve from 0.80260
# Epoch 69/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4333 - categorical_accuracy: 0.8005 - val_loss: 0.4151 - val_categorical_accuracy: 0.8028
#
# Epoch 00069: val_categorical_accuracy improved from 0.80260 to 0.80280, saving model to best_model.h5
# Epoch 70/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4301 - categorical_accuracy: 0.8014 - val_loss: 0.4082 - val_categorical_accuracy: 0.8043
#
# Epoch 00070: val_categorical_accuracy improved from 0.80280 to 0.80430, saving model to best_model.h5
# Epoch 71/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4255 - categorical_accuracy: 0.8037 - val_loss: 0.4125 - val_categorical_accuracy: 0.8031
#
# Epoch 00071: val_categorical_accuracy did not improve from 0.80430
# Epoch 72/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4172 - categorical_accuracy: 0.8071 - val_loss: 0.4032 - val_categorical_accuracy: 0.8085
#
# Epoch 00072: val_categorical_accuracy improved from 0.80430 to 0.80850, saving model to best_model.h5
# Epoch 73/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.4130 - categorical_accuracy: 0.8111 - val_loss: 0.4058 - val_categorical_accuracy: 0.8085
#
# Epoch 00073: val_categorical_accuracy did not improve from 0.80850
# Epoch 74/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4128 - categorical_accuracy: 0.8110 - val_loss: 0.4001 - val_categorical_accuracy: 0.8103
#
# Epoch 00074: val_categorical_accuracy improved from 0.80850 to 0.81030, saving model to best_model.h5
# Epoch 75/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.4073 - categorical_accuracy: 0.8136 - val_loss: 0.3911 - val_categorical_accuracy: 0.8157
#
# Epoch 00075: val_categorical_accuracy improved from 0.81030 to 0.81570, saving model to best_model.h5
# Epoch 76/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.4069 - categorical_accuracy: 0.8124 - val_loss: 0.3877 - val_categorical_accuracy: 0.8161
#
# Epoch 00076: val_categorical_accuracy improved from 0.81570 to 0.81610, saving model to best_model.h5
# Epoch 77/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3996 - categorical_accuracy: 0.8182 - val_loss: 0.3895 - val_categorical_accuracy: 0.8159
#
# Epoch 00077: val_categorical_accuracy did not improve from 0.81610
# Epoch 78/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3960 - categorical_accuracy: 0.8200 - val_loss: 0.3830 - val_categorical_accuracy: 0.8182
#
# Epoch 00078: val_categorical_accuracy improved from 0.81610 to 0.81820, saving model to best_model.h5
# Epoch 79/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3896 - categorical_accuracy: 0.8217 - val_loss: 0.3812 - val_categorical_accuracy: 0.8201
#
# Epoch 00079: val_categorical_accuracy improved from 0.81820 to 0.82010, saving model to best_model.h5
# Epoch 80/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3909 - categorical_accuracy: 0.8220 - val_loss: 0.3815 - val_categorical_accuracy: 0.8204
#
# Epoch 00080: val_categorical_accuracy improved from 0.82010 to 0.82040, saving model to best_model.h5
# Epoch 81/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3862 - categorical_accuracy: 0.8234 - val_loss: 0.3787 - val_categorical_accuracy: 0.8222
#
# Epoch 00081: val_categorical_accuracy improved from 0.82040 to 0.82220, saving model to best_model.h5
# Epoch 82/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3837 - categorical_accuracy: 0.8254 - val_loss: 0.3768 - val_categorical_accuracy: 0.8233
#
# Epoch 00082: val_categorical_accuracy improved from 0.82220 to 0.82330, saving model to best_model.h5
# Epoch 83/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3789 - categorical_accuracy: 0.8256 - val_loss: 0.3712 - val_categorical_accuracy: 0.8259
#
# Epoch 00083: val_categorical_accuracy improved from 0.82330 to 0.82590, saving model to best_model.h5
# Epoch 84/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3787 - categorical_accuracy: 0.8281 - val_loss: 0.3699 - val_categorical_accuracy: 0.8248
#
# Epoch 00084: val_categorical_accuracy did not improve from 0.82590
# Epoch 85/256
# 60000/60000 [==============================] - 19s 322us/step - loss: 0.3749 - categorical_accuracy: 0.8289 - val_loss: 0.3795 - val_categorical_accuracy: 0.8213
#
# Epoch 00085: val_categorical_accuracy did not improve from 0.82590
# Epoch 86/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3737 - categorical_accuracy: 0.8298 - val_loss: 0.3665 - val_categorical_accuracy: 0.8284
#
# Epoch 00086: val_categorical_accuracy improved from 0.82590 to 0.82840, saving model to best_model.h5
# Epoch 87/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3705 - categorical_accuracy: 0.8324 - val_loss: 0.3678 - val_categorical_accuracy: 0.8263
#
# Epoch 00087: val_categorical_accuracy did not improve from 0.82840
# Epoch 88/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3649 - categorical_accuracy: 0.8331 - val_loss: 0.3618 - val_categorical_accuracy: 0.8306
#
# Epoch 00088: val_categorical_accuracy improved from 0.82840 to 0.83060, saving model to best_model.h5
# Epoch 89/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3616 - categorical_accuracy: 0.8358 - val_loss: 0.3595 - val_categorical_accuracy: 0.8301
#
# Epoch 00089: val_categorical_accuracy did not improve from 0.83060
# Epoch 90/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3597 - categorical_accuracy: 0.8371 - val_loss: 0.3670 - val_categorical_accuracy: 0.8243
#
# Epoch 00090: val_categorical_accuracy did not improve from 0.83060
# Epoch 91/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3589 - categorical_accuracy: 0.8378 - val_loss: 0.3644 - val_categorical_accuracy: 0.8291
#
# Epoch 00091: val_categorical_accuracy did not improve from 0.83060
# Epoch 92/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3542 - categorical_accuracy: 0.8398 - val_loss: 0.3567 - val_categorical_accuracy: 0.8311
#
# Epoch 00092: val_categorical_accuracy improved from 0.83060 to 0.83110, saving model to best_model.h5
# Epoch 93/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3532 - categorical_accuracy: 0.8403 - val_loss: 0.3576 - val_categorical_accuracy: 0.8328
#
# Epoch 00093: val_categorical_accuracy improved from 0.83110 to 0.83280, saving model to best_model.h5
# Epoch 94/256
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.3492 - categorical_accuracy: 0.8423 - val_loss: 0.3536 - val_categorical_accuracy: 0.8359
#
# Epoch 00094: val_categorical_accuracy improved from 0.83280 to 0.83590, saving model to best_model.h5
# Epoch 95/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3465 - categorical_accuracy: 0.8429 - val_loss: 0.3498 - val_categorical_accuracy: 0.8354
#
# Epoch 00095: val_categorical_accuracy did not improve from 0.83590
# Epoch 96/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3443 - categorical_accuracy: 0.8450 - val_loss: 0.3578 - val_categorical_accuracy: 0.8335
#
# Epoch 00096: val_categorical_accuracy did not improve from 0.83590
# Epoch 97/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3434 - categorical_accuracy: 0.8461 - val_loss: 0.3484 - val_categorical_accuracy: 0.8384
#
# Epoch 00097: val_categorical_accuracy improved from 0.83590 to 0.83840, saving model to best_model.h5
# Epoch 98/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3404 - categorical_accuracy: 0.8463 - val_loss: 0.3475 - val_categorical_accuracy: 0.8373
#
# Epoch 00098: val_categorical_accuracy did not improve from 0.83840
# Epoch 99/256
# 60000/60000 [==============================] - 19s 319us/step - loss: 0.3370 - categorical_accuracy: 0.8488 - val_loss: 0.3595 - val_categorical_accuracy: 0.8322
#
# Epoch 00099: val_categorical_accuracy did not improve from 0.83840
# Epoch 100/256
# 60000/60000 [==============================] - 19s 321us/step - loss: 0.3356 - categorical_accuracy: 0.8494 - val_loss: 0.3455 - val_categorical_accuracy: 0.8392
#
# Epoch 00100: val_categorical_accuracy improved from 0.83840 to 0.83920, saving model to best_model.h5
# Epoch 101/256
# 13440/60000 [=====>........................] - ETA: 14s - loss: 0.3376 - categorical_accuracy: 0.8481

# %%
# evaluate loaded model
scores_train = saved_model.evaluate(xx_train, yy_train, verbose=0)
scores_test  = saved_model.evaluate(xx_test,  yy_test,  verbose=0)
scores_val   = saved_model.evaluate(xx_val,   yy_val,   verbose=0)
print("Accuracy Train: %.2f%% , Test: %.2f%% Val: %.2f%% " % (scores_train[1]*100, scores_test[1]*100, scores_val[1]*100))

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(cnn.history['loss'])

plt.figure(0)
plt.plot(cnn.history['categorical_accuracy'],'r')
plt.plot(cnn.history['val_categorical_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

plt.figure(1)
plt.plot(cnn.history['loss'],'r')
plt.plot(cnn.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
YY_pred = saved_model.predict(xx_val, verbose=2)
yy_pred = np.argmax(YY_pred, axis=2)

yy_test2 = np.argmax(yy_test, axis=2)



#confusion matrix
cm = confusion_matrix(np.argmax(yy_val,axis=2),yy_pred)
print(cm)

# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(num_classes),
                  range(num_classes))
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
def plot_results(plot_size=6):
  
  offset = max(0, min(len(YY_pred)-plot_size*plot_size, np.random.randint(0,len(YY_pred)/2)))

  plt.subplots_adjust(left=0.02, bottom=0.02, right=0.98, top=0.90, wspace=0.20, hspace=0.40)
  for i in range(min(plot_size/2,len(YY_pred)/plot_size)):
    for n in range(min(plot_size,len(YY_pred))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+n+1 )
      ax.imshow(xx_val[plot_size*i+n+offset,0])
      ax.axis('off')

    for n in range(min(plot_size,len(YY_pred))):
      ax = plt.subplot(plot_size,plot_size,plot_size*2*i+plot_size+n+1)
      x = np.arange(3)
      ax.bar(x, height = YY_pred[plot_size*i+n+offset,0], tick_label = class_names) 
      ax.axis('off')
      ax.set_title(class_names[int(np.argmax(YY_pred,axis=2)[plot_size*i+n+offset])])

  
  
  plt.show()
  #plt.savefig('event.png')
  #plt.clf()


plot_results(6)
plot_results(6)
plot_results(6)
plot_results(6)
plot_results(6)

plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
plot_results(2)
